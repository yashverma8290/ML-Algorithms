# %% [markdown]
# <a href="https://colab.research.google.com/github/yashverma8290/ML-Algorithms/blob/main/LR_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Linear Regression - Example 1

import numpy as np
import matplotlib.pyplot as plt

# Dummy data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Plotting the data
plt.scatter(x, y)
plt.title("Sample Data")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
